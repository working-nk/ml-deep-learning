# %%
from tensorflow import keras as k

# %% [markdown]
# ## Loading data and splitting it

# %%
mnist = k.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# ## Normalizing data and creating a model

# %%
# x_train = x_train/255
# x_test = x_test/255

x_train = k.utils.normalize(x_train, axis=1)
x_test = k.utils.normalize(x_test, axis=1)

model = k.models.Sequential()
model.add(k.layers.Flatten())
model.add(k.layers.Dense(128, activation='relu'))
model.add(k.layers.Dense(128, activation='relu'))
model.add(k.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3)
# Out:
# Train on 60000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.2605 - accuracy: 0.9247
# Epoch 2/3
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.1092 - accuracy: 0.9666
# Epoch 3/3
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0747 - accuracy: 0.9765

# %% [markdown]
# ## Evaluating model and making predictions

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
y_predict = model.predict([x_test])
print(y_predict)
# Out:
# [[1.25276420e-08 4.07750747e-07 1.85292491e-04 ... 9.99738276e-01
#   3.02612932e-07 6.19743830e-08]
#  [8.64856247e-06 5.69051423e-04 9.99224782e-01 ... 1.55571165e-08
#   4.81640473e-06 6.44488296e-10]
#  [3.57351162e-08 9.99798715e-01 1.44800269e-05 ... 2.88151587e-05
#   1.37732932e-04 1.05806828e-06]
#  ...
#  [8.12566636e-09 6.05844718e-07 1.00185844e-07 ... 4.77916410e-06
#   1.21733237e-05 5.97083708e-05]
#  [1.96335222e-07 1.76959725e-06 6.45770903e-09 ... 1.04303828e-08
#   2.71786936e-04 7.55429230e-09]
#  [5.70015175e-07 1.18893787e-07 5.85939461e-07 ... 2.18914686e-09
#   1.03706061e-05 9.18859158e-08]]

# %% [markdown]
# ## Using numpy to find out the highest possibility in this case 7

# %%
import numpy as np

# %%
print(np.argmax(y_predict[0]))
# Out:
# 7

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(x_test[0])

# %%
y_test[0]
# Out:
# 7
